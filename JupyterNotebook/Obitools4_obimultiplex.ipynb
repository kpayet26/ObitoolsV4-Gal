# %%
rm -rf obitools4
git clone https://github.com/metabarcoding/obitools4
# Out:
# Cloning into 'obitools4'...
# remote: Enumerating objects: 7574, done.
# remote: Counting objects: 100% (591/591), done.
# remote: Compressing objects: 100% (397/397), done.
# remote: Total 7574 (delta 287), reused 384 (delta 148), pack-reused 6983 (from 2)
# Receiving objects: 100% (7574/7574), 188.68 MiB | 22.14 MiB/s, done.
# Resolving deltas: 100% (4721/4721), done.
# Updating files: 100% (529/529), done.

# %%
### TEST FIXER LA VERSION 
cd obitools4
git reset --hard 996ec69
cd ..
# Out:
# HEAD is now at 996ec69 update the release notes for version 4.4.0

# %%
conda install -c conda-forge compilers=1.10 make=4.4.1 go=1.24.5 zlib=1.3.1 jq=1.8.1 --yes
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - bioconda
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.1
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - compilers=1.10
#     - go=1.24.5
#     - jq=1.8.1
#     - make=4.4.1
#     - zlib=1.3.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _go_select-2.2.0           |            nocgo           5 KB  conda-forge
#     binutils-2.43              |       h4852527_5          34 KB  conda-forge
#     binutils_linux-64-2.43     |       h4852527_4          35 KB  conda-forge
#     c-compiler-1.10.0          |       h2b85faf_0           7 KB  conda-forge
#     ca-certificates-2025.7.14  |       hbd8a1cb_0         152 KB  conda-forge
#     certifi-2025.7.14          |     pyhd8ed1ab_0         156 KB  conda-forge
#     compilers-1.10.0           |       ha770c72_0           7 KB  conda-forge
#     cxx-compiler-1.10.0        |       h1a2810e_0           6 KB  conda-forge
#     fortran-compiler-1.10.0    |       h36df796_0           6 KB  conda-forge
#     gcc-13.3.0                 |       h9576a4e_2          54 KB  conda-forge
#     gcc_impl_linux-64-13.3.0   |       h1e990d8_2        63.7 MB  conda-forge
#     gcc_linux-64-13.3.0        |      h6f18a23_11          32 KB  conda-forge
#     gfortran-13.3.0            |       h9576a4e_2          53 KB  conda-forge
#     gfortran_impl_linux-64-13.3.0|       h84c1745_2        15.2 MB  conda-forge
#     gfortran_linux-64-13.3.0   |      h1917dac_11          30 KB  conda-forge
#     go-1.24.5                  |       h1a1113d_0        60.4 MB  conda-forge
#     gxx-13.3.0                 |       h9576a4e_2          53 KB  conda-forge
#     gxx_impl_linux-64-13.3.0   |       hae580e1_2        12.7 MB  conda-forge
#     gxx_linux-64-13.3.0        |      hb14504d_11          30 KB  conda-forge
#     jq-1.8.1                   |       h73b1eb8_0         306 KB  conda-forge
#     kernel-headers_linux-64-5.14.0|       he073ed8_2         1.3 MB  conda-forge
#     libgcc-devel_linux-64-13.3.0|     hc03c837_102         2.5 MB  conda-forge
#     libsanitizer-13.3.0        |       he8ea267_2         4.0 MB  conda-forge
#     libstdcxx-devel_linux-64-13.3.0|     hc03c837_102        12.3 MB  conda-forge
#     oniguruma-6.9.10           |       hb9d3cd8_0         243 KB  conda-forge
#     openssl-3.5.1              |       h7b32b05_0         3.0 MB  conda-forge
#     sysroot_linux-64-2.34      |       h087de78_2        38.0 MB  conda-forge
#     zlib-1.3.1                 |       hb9d3cd8_2          90 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       214.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   _go_select         conda-forge/linux-64::_go_select-2.2.0-nocgo
#   binutils           conda-forge/linux-64::binutils-2.43-h4852527_5
#   binutils_impl_lin~ conda-forge/linux-64::binutils_impl_linux-64-2.43-h4bf12b8_4
#   binutils_linux-64  conda-forge/linux-64::binutils_linux-64-2.43-h4852527_4
#   c-compiler         conda-forge/linux-64::c-compiler-1.10.0-h2b85faf_0
#   compilers          conda-forge/linux-64::compilers-1.10.0-ha770c72_0
#   cxx-compiler       conda-forge/linux-64::cxx-compiler-1.10.0-h1a2810e_0
#   fortran-compiler   conda-forge/linux-64::fortran-compiler-1.10.0-h36df796_0
#   gcc                conda-forge/linux-64::gcc-13.3.0-h9576a4e_2
#   gcc_impl_linux-64  conda-forge/linux-64::gcc_impl_linux-64-13.3.0-h1e990d8_2
#   gcc_linux-64       conda-forge/linux-64::gcc_linux-64-13.3.0-h6f18a23_11
#   gfortran           conda-forge/linux-64::gfortran-13.3.0-h9576a4e_2
#   gfortran_impl_lin~ conda-forge/linux-64::gfortran_impl_linux-64-13.3.0-h84c1745_2
#   gfortran_linux-64  conda-forge/linux-64::gfortran_linux-64-13.3.0-h1917dac_11
#   go                 conda-forge/linux-64::go-1.24.5-h1a1113d_0
#   gxx                conda-forge/linux-64::gxx-13.3.0-h9576a4e_2
#   gxx_impl_linux-64  conda-forge/linux-64::gxx_impl_linux-64-13.3.0-hae580e1_2
#   gxx_linux-64       conda-forge/linux-64::gxx_linux-64-13.3.0-hb14504d_11
#   jq                 conda-forge/linux-64::jq-1.8.1-h73b1eb8_0
#   kernel-headers_li~ conda-forge/noarch::kernel-headers_linux-64-5.14.0-he073ed8_2
#   libgcc-devel_linu~ conda-forge/noarch::libgcc-devel_linux-64-13.3.0-hc03c837_102
#   libsanitizer       conda-forge/linux-64::libsanitizer-13.3.0-he8ea267_2
#   libstdcxx-devel_l~ conda-forge/noarch::libstdcxx-devel_linux-64-13.3.0-hc03c837_102
#   make               conda-forge/linux-64::make-4.4.1-hb9d3cd8_2
#   oniguruma          conda-forge/linux-64::oniguruma-6.9.10-hb9d3cd8_0
#   sysroot_linux-64   conda-forge/noarch::sysroot_linux-64-2.34-h087de78_2
#   zlib               conda-forge/linux-64::zlib-1.3.1-hb9d3cd8_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.7.14-hbd8a1cb_0
#   certifi                            2025.1.31-pyhd8ed1ab_0 --> 2025.7.14-pyhd8ed1ab_0
#   openssl                                  3.5.0-h7b32b05_0 --> 3.5.1-h7b32b05_0
#
#
#
# Downloading and Extracting Packages:
# gcc_impl_linux-64-13 | 63.7 MB   |                                       |   0%
# go-1.24.5            | 60.4 MB   |                                       |   0%
#
# sysroot_linux-64-2.3 | 38.0 MB   |                                       |   0%
#
#
# gfortran_impl_linux- | 15.2 MB   |                                       |   0%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   |                                       |   0%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   |                                       |   0%
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    |                                       |   0%
#
#
#
#
#
#
# openssl-3.5.1        | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# kernel-headers_linux | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# jq-1.8.1             | 306 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# oniguruma-6.9.10     | 243 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 90 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc-13.3.0           | 54 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran-13.3.0      | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx-13.3.0           | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_linux-64-2. | 35 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils-2.43        | 34 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-13.3.0  | 32 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran_linux-64-13 | 30 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_linux-64-13.3.0  | 30 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# gfortran_impl_linux- | 15.2 MB   |                                       |   0%
#
# gcc_impl_linux-64-13 | 63.7 MB   |                                       |   0%
# go-1.24.5            | 60.4 MB   |                                       |   0%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   |                                       |   0%
#
#
# gfortran_impl_linux- | 15.2 MB   | 9                                     |   3%
#
# gcc_impl_linux-64-13 | 63.7 MB   | 1                                     |   0%
# go-1.24.5            | 60.4 MB   | 2                                     |   1%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | 5                                     |   1%
#
#
# gfortran_impl_linux- | 15.2 MB   | #9                                    |   5%
#
# gcc_impl_linux-64-13 | 63.7 MB   | 3                                     |   1%
# go-1.24.5            | 60.4 MB   | 8                                     |   2%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ##3                                   |   6%
#
#
# gfortran_impl_linux- | 15.2 MB   | ###1                                  |   8%
#
# gcc_impl_linux-64-13 | 63.7 MB   | 5                                     |   2%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ###6                                  |  10%
# go-1.24.5            | 60.4 MB   | #1                                    |   3%
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | 8                                     |   2%
#
# sysroot_linux-64-2.3 | 38.0 MB   | #2                                    |   3%
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #                                     |   3%
# go-1.24.5            | 60.4 MB   | #4                                    |   4%
#
# sysroot_linux-64-2.3 | 38.0 MB   | #5                                    |   4%
#
#
# gfortran_impl_linux- | 15.2 MB   | ####8                                 |  13%
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #2                                    |   3%
# go-1.24.5            | 60.4 MB   | #7                                    |   5%
#
# sysroot_linux-64-2.3 | 38.0 MB   | #9                                    |   5%
#
#
# gfortran_impl_linux- | 15.2 MB   | #####8                                |  16%
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #6                                    |   4%
# go-1.24.5            | 60.4 MB   | ##                                    |   6%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ##5                                   |   7%
#
#
# gfortran_impl_linux- | 15.2 MB   | #######                               |  19%
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##                                    |   6%
# go-1.24.5            | 60.4 MB   | ##5                                   |   7%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ###                                   |   8%
#
#
# gfortran_impl_linux- | 15.2 MB   | ########9                             |  24%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ##########2                           |  28%
# go-1.24.5            | 60.4 MB   | ##9                                   |   8%
#
#
# gfortran_impl_linux- | 15.2 MB   | ##########3                           |  28%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##3                                   |   6%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ############2                         |  33%
# go-1.24.5            | 60.4 MB   | ###3                                  |   9%
#
#
# gfortran_impl_linux- | 15.2 MB   | ############3                         |  33%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##7                                   |   7%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ################                      |  43%
# go-1.24.5            | 60.4 MB   | ####2                                 |  11%
#
#
# gfortran_impl_linux- | 15.2 MB   | ###############7                      |  43%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ###4                                  |   9%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ###################9                  |  54%
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ####1                                 |  11%
# go-1.24.5            | 60.4 MB   | #####1                                |  14%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ######7                               |  18%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | #######################9              |  65%
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #####2                                |  14%
# go-1.24.5            | 60.4 MB   | ######2                               |  17%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ########6                             |  23%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ###########################7          |  75%
#
#
# gfortran_impl_linux- | 15.2 MB   | ###########################1          |  73%
# go-1.24.5            | 60.4 MB   | #######                               |  19%
#
# gcc_impl_linux-64-13 | 63.7 MB   | #####9                                |  16%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ###############################6      |  85%
#
#
# gfortran_impl_linux- | 15.2 MB   | ##############################7       |  83%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ######9                               |  19%
# go-1.24.5            | 60.4 MB   | ########1                             |  22%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ####################################6 |  99%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ############5                         |  34%
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #######6                              |  21%
# go-1.24.5            | 60.4 MB   | #########2                            |  25%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ########6                             |  23%
# go-1.24.5            | 60.4 MB   | ##########5                           |  29%
#
# gcc_impl_linux-64-13 | 63.7 MB   | #########8                            |  27%
# go-1.24.5            | 60.4 MB   | ###########6                          |  31%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##########9                           |  30%
# go-1.24.5            | 60.4 MB   | ############8                         |  35%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ############                          |  33%
# go-1.24.5            | 60.4 MB   | ##############1                       |  38%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ##################################### | 100%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   |                                       |   0%
#
# sysroot_linux-64-2.3 | 38.0 MB   | #####################4                |  58%
# gcc_impl_linux-64-13 | 63.7 MB   | #############                         |  35%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ####3                                 |  12%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##############                        |  38%
# go-1.24.5            | 60.4 MB   | ################3                     |  44%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | #######4                              |  20%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ########################6             |  67%
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ###############                       |  41%
#
#
# gfortran_impl_linux- | 15.2 MB   | ##################################### | 100%
#
#
# gfortran_impl_linux- | 15.2 MB   | ##################################### | 100%
# go-1.24.5            | 60.4 MB   | #################4                    |  47%
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | 1                                     |   0%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ############9                         |  35%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ##########################2           |  71%
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ###############8                      |  43%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ###############7                      |  43%
# go-1.24.5            | 60.4 MB   | ##################3                   |  50%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ###########################6          |  75%
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | ###############                       |  41%
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ################5                     |  45%
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | ####################7                 |  56%
# go-1.24.5            | 60.4 MB   | ###################                   |  52%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ####################4                 |  55%
#
# gcc_impl_linux-64-13 | 63.7 MB   | #################                     |  46%
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | ##########################5           |  72%
# go-1.24.5            | 60.4 MB   | ###################6                  |  53%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ######################5               |  61%
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | ################################8     |  89%
#
# gcc_impl_linux-64-13 | 63.7 MB   | #################6                    |  48%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ########################8             |  67%
# go-1.24.5            | 60.4 MB   | ####################2                 |  55%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##################1                   |  49%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ###########################5          |  74%
# go-1.24.5            | 60.4 MB   | ####################8                 |  56%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##################7                   |  51%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | #############################8        |  81%
# go-1.24.5            | 60.4 MB   | #####################3                |  58%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ################################6     |  88%
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | ##################################### | 100%
# go-1.24.5            | 60.4 MB   | ######################1               |  60%
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ###################2                  |  52%
#
#
#
#
#
#
# openssl-3.5.1        | 3.0 MB    | 1                                     |   1%
#
# sysroot_linux-64-2.3 | 38.0 MB   | #################################4    |  90%
#
#
#
#
#
#
# openssl-3.5.1        | 3.0 MB    | ######1                               |  17%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ##################################3   |  93%
# gcc_impl_linux-64-13 | 63.7 MB   | ###################6                  |  53%
#
#
#
#
#
#
# openssl-3.5.1        | 3.0 MB    | ############3                         |  33%
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | ####################################3 |  98%
#
# gcc_impl_linux-64-13 | 63.7 MB   | ####################                  |  54%
#
#
#
#
#
#
# openssl-3.5.1        | 3.0 MB    | ###################5                  |  53%
# go-1.24.5            | 60.4 MB   | #######################3              |  63%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ##################################8   |  94%
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ####################4                 |  55%
#
#
#
#
#
#
# openssl-3.5.1        | 3.0 MB    | #################################1    |  89%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ###################################5  |  96%
# gcc_impl_linux-64-13 | 63.7 MB   | ####################7                 |  56%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ####################################  |  98%
# gcc_impl_linux-64-13 | 63.7 MB   | #####################                 |  57%
# go-1.24.5            | 60.4 MB   | ########################5             |  66%
#
# gcc_impl_linux-64-13 | 63.7 MB   | #####################2                |  58%
# go-1.24.5            | 60.4 MB   | ########################9             |  67%
# go-1.24.5            | 60.4 MB   | #########################2            |  68%
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #####################5                |  58%
# go-1.24.5            | 60.4 MB   | #########################9            |  70%
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ######################                |  60%
# go-1.24.5            | 60.4 MB   | ##########################3           |  71%
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ######################4               |  61%
# go-1.24.5            | 60.4 MB   | ##########################9           |  73%
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #######################               |  62%
# go-1.24.5            | 60.4 MB   | ###########################5          |  75%
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #######################4              |  64%
# go-1.24.5            | 60.4 MB   | ############################1         |  76%
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ########################2             |  66%
#
#
#
#
#
#
#
#
# kernel-headers_linux | 1.3 MB    | 4                                     |   1%
# go-1.24.5            | 60.4 MB   | ############################8         |  78%
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ########################9             |  67%
#
#
#
#
#
#
#
#
#
# jq-1.8.1             | 306 KB    | #9                                    |   5%
#
#
#
#
#
#
#
#
# kernel-headers_linux | 1.3 MB    | ###################8                  |  54%
# go-1.24.5            | 60.4 MB   | #############################4        |  80%
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #########################4            |  69%
# go-1.24.5            | 60.4 MB   | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
# oniguruma-6.9.10     | 243 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
# oniguruma-6.9.10     | 243 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# kernel-headers_linux | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | ###8                                  |  11%
# go-1.24.5            | 60.4 MB   | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 90 KB     | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##########################4           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran-13.3.0      | 53 KB     | ###########                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc-13.3.0           | 54 KB     | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran-13.3.0      | 53 KB     | ##################################### | 100%
# go-1.24.5            | 60.4 MB   | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx-13.3.0           | 53 KB     | ###########                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_linux-64-2. | 35 KB     | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx-13.3.0           | 53 KB     | ##################################### | 100%
# go-1.24.5            | 60.4 MB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils-2.43        | 34 KB     | #################1                    |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-13.3.0  | 32 KB     | ##################6                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-13.3.0  | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils-2.43        | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran_linux-64-13 | 30 KB     | ###################6                  |  53%
# go-1.24.5            | 60.4 MB   | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ###########################5          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran_linux-64-13 | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_linux-64-13.3.0  | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# gcc_impl_linux-64-13 | 63.7 MB   | ###########################8          |  75%
# gcc_impl_linux-64-13 | 63.7 MB   | ############################1         |  76%
# gcc_impl_linux-64-13 | 63.7 MB   | ############################8         |  78%
# gcc_impl_linux-64-13 | 63.7 MB   | #############################7        |  81%
# gcc_impl_linux-64-13 | 63.7 MB   | ##############################7       |  83%
# gcc_impl_linux-64-13 | 63.7 MB   | ###############################4      |  85%
# go-1.24.5            | 60.4 MB   | ####################################6 |  99%
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ####################################2 |  98%
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ##################################### | 100%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ##################################### | 100%
#
#
#
#
#
#
# openssl-3.5.1        | 3.0 MB    | ##################################### | 100%
#
#
# gfortran_impl_linux- | 15.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# jq-1.8.1             | 306 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# jq-1.8.1             | 306 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# oniguruma-6.9.10     | 243 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# oniguruma-6.9.10     | 243 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 90 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 90 KB     | ##################################### | 100%
# go-1.24.5            | 60.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran-13.3.0      | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran-13.3.0      | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc-13.3.0           | 54 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx-13.3.0           | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx-13.3.0           | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_linux-64-2. | 35 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_linux-64-2. | 35 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-13.3.0  | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-13.3.0  | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils-2.43        | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils-2.43        | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran_linux-64-13 | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gfortran_linux-64-13 | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_linux-64-13.3.0  | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_linux-64-13.3.0  | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
# kernel-headers_linux | 1.3 MB    | ##################################### | 100%
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ##################################### | 100%
#
# sysroot_linux-64-2.3 | 38.0 MB   | ##################################### | 100%
# go-1.24.5            | 60.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# CHANGER LE LIEN DU GITLAB EN GITHUB
find . -type f -exec sed -i \
  -e 's|git\.metabarcoding\.org/obitools/obitools4/obitools4|github.com/metabarcoding/obitools4|g' \
  -e 's|git\.metabarcoding\.org/org-asm/org-asm\.git|github.com/metabarcoding/org-asm.git|g' \
  -e 's|git\.metabarcoding\.org/lecasofts/go/obitools|github.com/metabarcoding/obitools4|g' \
  -e 's|https://git\.metabarcoding\.org|https://github.com/metabarcoding|g' \
  {} +

# %%
export CC=$CONDA_PREFIX/bin/x86_64-conda-linux-gnu-cc
export CGO_ENABLED=1
export CGO_CFLAGS="-I$CONDA_PREFIX/include"
export CGO_LDFLAGS="-L$CONDA_PREFIX/lib"

# %%
cd obitools4
make
cd ..
# Out:
# mkdir -p build
# Update version.go : pkg/obioptions/version.go to Release 4.4.0 (996ec69)
# - Building obitool obiannotate...Done.
# - Building obitool obiclean...Done.
# - Building obitool obicleandb...Done.
# - Building obitool obicomplement...Done.
# - Building obitool obiconsensus...Done.
# - Building obitool obiconvert...Done.
# - Building obitool obicount...Done.
# - Building obitool obicsv...Done.
# - Building obitool obidemerge...Done.
# - Building obitool obidistribute...Done.
# - Building obitool obigrep...Done.
# - Building obitool obijoin...Done.
# - Building obitool obikmermatch...Done.
# - Building obitool obikmersimcount...Done.
# - Building obitool obilandmark...Done.
# - Building obitool obimatrix...Done.
# - Building obitool obimicrosat...Done.
# - Building obitool obimultiplex...Done.
# - Building obitool obipairing...Done.
# - Building obitool obipcr...Done.
# - Building obitool obireffamidx...Done.
# - Building obitool obirefidx...Done.
# - Building obitool obiscript...Done.
# - Building obitool obisplit...Done.
# - Building obitool obisummary...Done.
# - Building obitool obitag...Done.
# - Building obitool obitagpcr...Done.
# - Building obitool obitaxonomy...Done.
# - Building obitool obiuniq...Done.

# %%
json_path="galaxy_inputs/galaxy_inputs.json"

# input_file="galaxy_inputs/wolfdiet_obigrep.fastq" test injection d'input
input_file="$(grep -o '"path": *"[^"]*"' "$json_path" | head -n 1 | sed 's/.*"path": *"\([^"]*\)".*/\1/')"

echo "Input file path: $input_file"


filename=$(basename -- "$input_file")       # ex: myfile.fastq.gz
extension="${filename##*.}"                # ex: gz
filename="${filename%.*}"                  # ex: myfile.fastq ou myfile

echo "Nom de fichier (sans chemin, sans extension) : $filename"
echo "Extension détectée : $extension"

output_file="outputs/outputfile.fastqsanger"
format=""

## Chemin ngs filter

ngs_file=$(jq -r '.ngs[0].path' galaxy_inputs/galaxy_inputs.json)
# Out:
# Input file path: galaxy_inputs/inputfile/Suiteobigrep.fastqsanger.fastq
# Nom de fichier (sans chemin, sans extension) : Suiteobigrep.fastqsanger
# Extension détectée : fastq

# %%
./obitools4/build/obimultiplex -s $ngs_file $input_file --out $output_file
# Out:
# INFO[0000] Number of workers set 8
# INFO[0000] Found 1 files to process
# INFO[0000] /data/jwd06/pulsar_staging/86578375/inputs/dataset_b9b3bf50-e1a9-43b3-8e7c-88fd60aa1a20.dat mime type: text/fastq
# INFO[0000] Reading NGSFilter file: galaxy_inputs/ngs/wolf_diet_ngsfilter.tabular
# INFO[0000] NGSFilter configuration mimetype: text/plain; charset=utf-8
# INFO[0000] Discards unassigned sequences
# INFO[0000] Sequence demultiplexing using 8 workers
# INFO[0000] On output use JSON headers
# \ Reading sequences (44716/-, 4995 it/s) [8s]
